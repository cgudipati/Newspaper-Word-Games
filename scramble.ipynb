# %% [markdown]
# # Scramble Solver

# %% [markdown]
# ![word%20scramble.jpg](attachment:word%20scramble.jpg)

# %% [markdown]
# ### Here, we go word by word manually...
# So for the first question "duegn", we'd get "nudge" as the output. <br>
# If the question has multiple answers, all of them will be displayed.

# %%
total_letters = input("please enter the word: ")
# Out:
# please enter the word: duegn

# %%
f = open(r"corncob_lowercase.txt", "r")
#print(f.read())
wordslist = f.read()
words = wordslist.splitlines()
#words

# %%
#total_letters = "dgeeo"

# %%
from itertools import permutations

# %%
l = list(permutations(total_letters))
#l

# %%
def convertTuple(tup):
    str1 =  ''.join(tup)
    return str1

# %%
tuple_now = l[2]
str_now = convertTuple(tuple_now)
print(str_now)
# Out:
# dugen

# %%
word_final = []

# %%
for i in range(0,len(l)):
    if(convertTuple(l[i]) in words):
        print(convertTuple(l[i]))
        if (convertTuple(l[i]) not in word_final):
            word_final.append(convertTuple(l[i]))
# Out:
# nudge

# %%
for i in word_final:
    print(i)
# Out:
# nudge
