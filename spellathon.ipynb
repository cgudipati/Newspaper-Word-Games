# %% [markdown]
# # Spellathon Solver

# %% [markdown]
# ![spellathon.jpg](attachment:spellathon.jpg)

# %% [markdown]
# ## Here's the desired output of the code for the above example
# #### (where the user input would be 'rlawdor', since the central letter must be at the beginning of the string)
#
# road <br>
# roar <br>
# lard <br>
# lord <br>
# ward <br>
# word <br>
# draw <br>
# oral <br>
# arrow <br>
# world <br>
# drawl <br>
# warlord

# %%
total_letters = input("please enter the hexagon, with the middle/compulsory letter at the beginning")
important_letter = total_letters[0]
other_letters = list(total_letters[1:])
print(important_letter)
print(other_letters)
# Out:
# please enter the hexagon, with the middle/compulsory letter at the beginningrlawdor
# r
# ['l', 'a', 'w', 'd', 'o', 'r']

# %%
f = open(r"corncob_lowercase.txt", "r")
#print(f.read())
wordslist = f.read()
words = wordslist.splitlines()
#words

# %% [markdown]
# #### Use the cell below if you are not able to use the user input function at the beginning of the code.

# %%
#important_letter = 'r'
#other_letters = ['l','a','w','d','o','r']
#total_letters = "rlawdor"

# %%
from itertools import permutations

# %%
li = []
for n in range(4,8):
    l = list(permutations(total_letters,n))
    li.append(list(permutations(total_letters,n)))
    #print(l,"\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n")

# %%
#print(li)

# %%
def convertTuple(tup):
    str1 =  ''.join(tup)
    return str1

# %%
wordlist_new = []

# %%
for i in range(0,len(li)):
    for j in range(0,len(li[i])):
        #if (li[i][j] in ):
        #if (important_letter in li[i][j]):
        tuple_now = li[i][j]
        if (important_letter in tuple_now):
            str_now = convertTuple(tuple_now)
            #print(str_now)
            if (str_now in words):
                print(str_now)
                if(str_now not in wordlist_new):
                    wordlist_new.append(str_now)
# Out:
# road
# roar
# lard
# lard
# lord
# lord
# ward
# ward
# word
# word
# draw
# draw
# oral
# oral
# roar
# road
# arrow
# arrow
# world
# world
# drawl
# drawl
# warlord
# warlord

# %%
for i in wordlist_new:
    print(i)
# Out:
# road
# roar
# lard
# lord
# ward
# word
# draw
# oral
# arrow
# world
# drawl
# warlord
